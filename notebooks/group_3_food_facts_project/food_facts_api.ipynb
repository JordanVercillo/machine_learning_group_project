# %%
import requests
import pandas as pd

def fetch_products(query, query_type="search", page_size=100, page=1, sort_by="created_t"):

    if query_type == "brand":
        # Brand-based search
        url = f"https://world.openfoodfacts.org/brand/{query}.json"
        params = {
            "page_size": page_size,
            "page": page,
            "sort_by": sort_by
        }
    else:
        # Search term-based search
        url = "https://world.openfoodfacts.org/cgi/search.pl"
        params = {
            "search_terms": query,
            "search_simple": 1,
            "action": "process",
            "json": 1,
            "page_size": page_size,
            "page": page,
            "sort_by": sort_by
        }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        raise Exception(f"API request failed: {response.status_code}")

    data = response.json()
    return data.get("products", [])

def extract_product_fields(product):
    nutriments = product.get("nutriments", {})
    return {
        # Identifiers
        "product_name": product.get("product_name", "N/A"),
        "brands": product.get("brands", "N/A"),
        "barcode": product.get("code", "N/A"),
        "categories": ", ".join(product.get("categories_tags", [])),
        "countries": ", ".join(product.get("countries_tags", [])),
        "image_url": product.get("image_url", "N/A"),
        "ingredients_text": product.get("ingredients_text", "N/A"),

        # Nutrition values
        "energy_kcal_100g": nutriments.get("energy-kcal_100g"),
        "fat_100g": nutriments.get("fat_100g"),
        "saturated_fat_100g": nutriments.get("saturated-fat_100g"),
        "carbohydrates_100g": nutriments.get("carbohydrates_100g"),
        "sugars_100g": nutriments.get("sugars_100g"),
        "fiber_100g": nutriments.get("fiber_100g"),
        "proteins_100g": nutriments.get("proteins_100g"),
        "salt_100g": nutriments.get("salt_100g"),

        # Nutrition grade and labels
        "nutrition_grade": product.get("nutrition_grades_tags", [None])[0],
        "nova_group": product.get("nova_group"),
        "ecoscore_grade": product.get("ecoscore_grade"),
        "labels": ", ".join(product.get("labels_tags", [])),
        "allergens": ", ".join(product.get("allergens_tags", [])),
        "packaging": ", ".join(product.get("packaging_tags", [])),

        # Timestamps
        "created_t": product.get("created_t"),
        "last_modified_t": product.get("last_modified_t"),
    }

def search_and_extract_all(query, query_type="search", page_size=100, sort_by="created_t", max_pages=None):

    all_records = []
    page = 1

    while True:
        print(f"Fetching page {page}...")
        products = fetch_products(query, query_type=query_type, page_size=page_size, page=page, sort_by=sort_by)

        if not products:
            print("No more products found.")
            break

        for product in products:
            record = extract_product_fields(product)
            all_records.append(record)

        if max_pages is not None and page >= max_pages:
            print("Reached max_pages limit.")
            break

        page += 1

    df = pd.DataFrame(all_records)
    return df

# %%
#Single brand example
# df_oreo = search_and_extract_all("oreo", query_type="brand")
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# No more products found.

# %%
import pandas as pd

# Load brand names
brands_df = pd.read_csv(r"C:\Users\jverc\Downloads\Cleaned_Brand_Rankings.csv")
brand_list = brands_df["Brand"].dropna().unique().tolist()  

# Collecting results
all_brand_products = []

# %%
import time

# Loop through each brand and fetch data
for brand in brand_list:
    try:
        print(f"Searching brand: {brand}")
        df_brand = search_and_extract_all(brand, query_type="brand")  # Adjust max_pages as needed

        if df_brand.empty:
            print(f"No results for brand: {brand}")
            continue

        df_brand["searched_brand"] = brand  # Keep track of where each row came from
        all_brand_products.append(df_brand)

        time.sleep(1)  # Avoid hammering the API

    except Exception as e:
        print(f"Skipping brand '{brand}' due to error: {e}")

# Combine everything into one big DataFrame
df_all_brands = pd.concat(all_brand_products, ignore_index=True)
# Out:
# Searching brand: M&M's
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Ritz
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Frito-Lay
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Lay's
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# No more products found.
# Searching brand: Betty Crocker
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Heinz Ketchup
# Fetching page 1...
# Skipping brand 'Heinz Ketchup' due to error: API request failed: 404
# Searching brand: Jif
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Kit Kat
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Oreo
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# No more products found.
# Searching brand: Rice Krispies Treats
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Snickers
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# No more products found.
# Searching brand: Fritos
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Reese's
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# No more products found.
# Searching brand: Chips Ahoy!
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Doritos
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# No more products found.
# Searching brand: Cheez-It
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Hershey's
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# No more products found.
# Searching brand: Kellogg's
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# Fetching page 18...
# Fetching page 19...
# Fetching page 20...
# Fetching page 21...
# Fetching page 22...
# Fetching page 23...
# Fetching page 24...
# No more products found.
# Searching brand: Quaker
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# No more products found.
# Searching brand: Twix
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# No more products found.
# Searching brand: Tostitos
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Dove (chocolate)
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Heinz
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# Fetching page 18...
# Fetching page 19...
# Fetching page 20...
# Fetching page 21...
# No more products found.
# Searching brand: Pillsbury
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# No more products found.
# Searching brand: Dove
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: French's Mustard
# Fetching page 1...
# Skipping brand 'French's Mustard' due to error: API request failed: 404
# Searching brand: Lay's Chips
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Cheerios
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Planters
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Lifesavers
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Ferrero Rocher
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Smucker's
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Cheetos
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# No more products found.
# Searching brand: McCormick
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# No more products found.
# Searching brand: Orville Redenbacher's
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Kraft Foods
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Ruffles
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# No more products found.
# Searching brand: Goldfish
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Pringles
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# No more products found.
# Searching brand: Dove Chocolate Candy Bar
# Fetching page 1...
# Skipping brand 'Dove Chocolate Candy Bar' due to error: API request failed: 404
# Searching brand: Sargento
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Land O'Lakes
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Milky Way
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Breyers
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Ghirardelli
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Nature Valley
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# No more products found.
# Searching brand: Ben & Jerry's
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Jolly Rancher
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Tostitos Scoops
# Fetching page 1...
# Skipping brand 'Tostitos Scoops' due to error: API request failed: 404
# Searching brand: Campbell's
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# No more products found.
# Searching brand: Old El Paso
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# No more products found.
# Searching brand: General Mills
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# No more products found.
# Searching brand: Starburst
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Teddy Grahams
# Fetching page 1...
# Skipping brand 'Teddy Grahams' due to error: API request failed: 404
# Searching brand: Hidden Valley Ranch
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Nesquik
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# No more products found.
# Searching brand: Honey Bunches of Oats
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Eggo
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Hostess CupCake
# Fetching page 1...
# Skipping brand 'Hostess CupCake' due to error: API request failed: 404
# Searching brand: Heinz Mustard
# Fetching page 1...
# Skipping brand 'Heinz Mustard' due to error: API request failed: 404
# Searching brand: Sargento String Cheese
# Fetching page 1...
# Skipping brand 'Sargento String Cheese' due to error: API request failed: 404
# Searching brand: Frosted Flakes
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Bisquick
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Yoplait
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# Fetching page 18...
# Fetching page 19...
# Fetching page 20...
# No more products found.
# Searching brand: Butterfinger
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Honey Nut Cheerios
# Fetching page 1...
# Skipping brand 'Honey Nut Cheerios' due to error: API request failed: 404
# Searching brand: Chiquita
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Tabasco
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Cinnamon Toast Crunch
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Milky Way bar
# Fetching page 1...
# Skipping brand 'Milky Way bar' due to error: API request failed: 404
# Searching brand: King's Hawaiian
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Almond Joy
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Jimmy Dean
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Werther's Original
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Orville Redenbacher's Popcorn
# Fetching page 1...
# Skipping brand 'Orville Redenbacher's Popcorn' due to error: API request failed: 404
# Searching brand: Land O Lakes (butter)
# Fetching page 1...
# Skipping brand 'Land O Lakes (butter)' due to error: API request failed: 404
# Searching brand: Thin Mints Girl Scout Cookies
# Fetching page 1...
# Skipping brand 'Thin Mints Girl Scout Cookies' due to error: API request failed: 404
# Searching brand: Sunchips
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Three Musketeers
# Fetching page 1...
# Skipping brand 'Three Musketeers' due to error: API request failed: 404
# Searching brand: Mr. Goodbar
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: SweetTarts
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Special K
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Progresso
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Nabisco
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# No more products found.
# Searching brand: Cool Ranch Doritos
# Fetching page 1...
# Skipping brand 'Cool Ranch Doritos' due to error: API request failed: 404
# Searching brand: Oscar Mayer
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Tyson
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# No more products found.
# Searching brand: Kraft Mac & Cheese
# Fetching page 1...
# Skipping brand 'Kraft Mac & Cheese' due to error: API request failed: 404
# Searching brand: Milk Duds
# Fetching page 1...
# Skipping brand 'Milk Duds' due to error: API request failed: 404
# Searching brand: Tootsie Pop
# Fetching page 1...
# Skipping brand 'Tootsie Pop' due to error: API request failed: 404
# Searching brand: Pez Candy Dispenser
# Fetching page 1...
# Skipping brand 'Pez Candy Dispenser' due to error: API request failed: 404
# Searching brand: Cadbury Egg
# Fetching page 1...
# Skipping brand 'Cadbury Egg' due to error: API request failed: 404
# Searching brand: Hunt's Ketchup
# Fetching page 1...
# Skipping brand 'Hunt's Ketchup' due to error: API request failed: 404
# Searching brand: Skittles
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# No more products found.
# Searching brand: Great Value
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# No more products found.
# Searching brand: Rolo
# Fetching page 1...
# Fetching page 2...
# No more products found.
# Searching brand: Chex
# Fetching page 1...
# Fetching page 2...
# No more products found.
# C:\Users\jverc\AppData\Local\Temp\ipykernel_46600\3840281283.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_brands = pd.concat(all_brand_products, ignore_index=True)

# %%
df_all_brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23352 entries, 0 to 23351
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_name        23352 non-null  object
#  1   brands              23352 non-null  object
#  2   barcode             23352 non-null  object
#  3   categories          23352 non-null  object
#  4   countries           23352 non-null  object
#  5   image_url           23352 non-null  object
#  6   ingredients_text    23352 non-null  object
#  7   energy_kcal_100g    19622 non-null  float64
#  8   fat_100g            20073 non-null  float64
#  9   saturated_fat_100g  19156 non-null  float64
#  10  carbohydrates_100g  20046 non-null  float64
#  11  sugars_100g         19396 non-null  float64
#  12  fiber_100g          13234 non-null  float64
#  13  proteins_100g       20092 non-null  float64
#  14  salt_100g           19039 non-null  float64
#  15  nutrition_grade     23351 non-null  object
#  16  nova_group          12493 non-null  float64
#  17  ecoscore_grade      0 non-null      object
#  18  labels              23352 non-null  object
#  19  allergens           23352 non-null  object
#  20  packaging           23352 non-null  object
#  21  created_t           23352 non-null  int64
#  22  last_modified_t     23352 non-null  int64
#  23  searched_brand      23352 non-null  object
# dtypes: float64(9), int64(2), object(13)
# memory usage: 4.3+ MB

# %%
df_all_brands
# Out:
#                             product_name               brands        barcode  \
# 0                        Hirschenttecote                    M  2186307018257
# 1                           Rehschnitzel                    M  2186401010256
# 2                        Rindsfiletspitz                    M  2170639010102
# 3                Memories soft doughnuts                    M  6281016014432
# 4                         Enoki Mushroom                   m.  8719324855686
# ...                                  ...                  ...            ...
# 23347                          Corn Chex                 Chex  0016000208193
# 23348        Chex Mix Remix Cheesy Pizza                 Chex  0016000205536
# 23349             Honey Nut Flavour Chex  Chex, General Mills  0065633405226
# 23350         Check Mix Bold Party Blend                 Chex  0016000126077
# 23351  Chex cereal honey nut gluten free   General Mills,Chex  0016000487925
#
#                                               categories  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 23347
# 23348
# 23349  en:plant-based-foods-and-beverages, en:plant-b...
# 23350                                          en:snacks
# 23351  en:plant-based-foods-and-beverages, en:plant-b...
#
#                   countries  \
# 0                en:germany
# 1                en:germany
# 2                en:germany
# 3           en:saudi-arabia
# 4                en:germany
# ...                     ...
# 23347      en:united-states
# 23348      en:united-states
# 23349  en:canada, en:france
# 23350      en:united-states
# 23351      en:united-states
#
#                                                image_url  \
# 0                                                    N/A
# 1                                                    N/A
# 2                                                    N/A
# 3      https://images.openfoodfacts.org/images/produc...
# 4      https://images.openfoodfacts.org/images/produc...
# ...                                                  ...
# 23347                                                N/A
# 23348  https://images.openfoodfacts.org/images/produc...
# 23349  https://images.openfoodfacts.org/images/produc...
# 23350  https://images.openfoodfacts.org/images/produc...
# 23351  https://images.openfoodfacts.org/images/produc...
#
#                                         ingredients_text  energy_kcal_100g  \
# 0                                                    N/A               NaN
# 1                                                    N/A               NaN
# 2                                                    N/A               NaN
# 3                                                    N/A               NaN
# 4                                                    N/A               NaN
# ...                                                  ...               ...
# 23347  Whole Grain Corn, Corn Meal, Sugar, Corn Starc...             385.0
# 23348                                                N/A             433.0
# 23349  Whole grain corn, Degermed corn meal, Sugar, C...             382.0
# 23350  whole wheat, degermed yellow corn meal, enrich...             414.0
# 23351  whole grain corn, corn meal,sugar, corn starch...             372.0
#
#        fat_100g  saturated_fat_100g  ...  salt_100g  nutrition_grade  \
# 0           NaN                 NaN  ...        NaN          unknown
# 1           NaN                 NaN  ...        NaN          unknown
# 2           NaN                 NaN  ...        NaN          unknown
# 3           NaN                 NaN  ...        NaN          unknown
# 4           NaN                 NaN  ...        NaN          unknown
# ...         ...                 ...  ...        ...              ...
# 23347      2.56               0.000  ...     1.7900          unknown
# 23348     13.30               5.000  ...     2.1700          unknown
# 23349      1.47               0.294  ...     1.6200                e
# 23350     10.34               1.720  ...     1.8393                d
# 23351      3.49                 NaN  ...     1.5100          unknown
#
#        nova_group  ecoscore_grade  \
# 0             NaN            None
# 1             NaN            None
# 2             NaN            None
# 3             NaN            None
# 4             NaN            None
# ...           ...             ...
# 23347         NaN            None
# 23348         NaN            None
# 23349         4.0            None
# 23350         4.0            None
# 23351         4.0            None
#
#                                                   labels  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 23347
# 23348
# 23349  en:no-gluten, en:kosher, en:no-artificial-flav...
# 23350
# 23351                                       en:no-gluten
#
#                              allergens  packaging   created_t last_modified_t  \
# 0                                                  1728501068      1728501068
# 1                                                  1728501011      1728501011
# 2                                                  1728500921      1728500921
# 3                                                  1725361622      1753615692
# 4                                                  1699977550      1699977600
# ...                                ...        ...         ...             ...
# 23347                                              1715475353      1750005657
# 23348                                              1713149280      1749687013
# 23349                          en:nuts             1577892911      1713560486
# 23350  en:gluten, en:milk, en:soybeans             1524696090      1749423732
# 23351                                      en:box  1449344517      1745448564
#
#       searched_brand
# 0              M&M's
# 1              M&M's
# 2              M&M's
# 3              M&M's
# 4              M&M's
# ...              ...
# 23347           Chex
# 23348           Chex
# 23349           Chex
# 23350           Chex
# 23351           Chex
#
# [23352 rows x 24 columns]

# %%
df_all_brands.describe()
# Out:
#        energy_kcal_100g      fat_100g  saturated_fat_100g  carbohydrates_100g  \
# count      19622.000000  20073.000000        19156.000000        20046.000000
# mean         364.063886     17.020787            4.718700           45.720592
# std          198.800476     15.197570            6.072983           26.783914
# min            0.000000      0.000000            0.000000            0.000000
# 25%          199.250000      3.030000            1.000000           17.187500
# 50%          412.000000     15.500000            3.100000           53.600000
# 75%          505.000000     28.600000            5.900000           64.300000
# max        10000.000000    350.000000          265.700000          700.000000
#
#         sugars_100g    fiber_100g  proteins_100g     salt_100g    nova_group  \
# count  19396.000000  13234.000000   20092.000000  19039.000000  12493.000000
# mean      16.479548      3.840949       6.699974      2.614299      3.787801
# std       18.701916      4.272045      11.963559     46.732356      0.588505
# min        0.000000      0.000000       0.000000      0.000000      1.000000
# 25%        3.000000      1.200000       3.450000      0.380000      4.000000
# 50%        8.510000      3.570000       6.060606      0.925000      4.000000
# 75%       26.000000      4.800000       7.666667      1.451950      4.000000
# max      550.000000     90.000000    1500.000000   3450.000000      4.000000
#
#           created_t  last_modified_t
# count  2.335200e+04     2.335200e+04
# mean   1.614233e+09     1.715446e+09
# std    1.001926e+08     5.216798e+07
# min    1.332525e+09     1.424947e+09
# 25%    1.536033e+09     1.689323e+09
# 50%    1.613223e+09     1.745436e+09
# 75%    1.715160e+09     1.748663e+09
# max    1.754004e+09     1.754006e+09

# %%
import re


cols_to_check = [
    "energy_kcal_100g", "fat_100g", "saturated_fat_100g",
    "carbohydrates_100g", "sugars_100g", "fiber_100g",
    "proteins_100g", "salt_100g"
]

non_zero_mask = pd.Series(True, index=df_all_brands.index)

for col in cols_to_check:
    non_zero_mask &= df_all_brands[col].notna() & (df_all_brands[col] != 0)

df_clean = df_all_brands[
    (df_all_brands["energy_kcal_100g"] > 20) &
    (df_all_brands["energy_kcal_100g"] <= 900) &

    (df_all_brands["fat_100g"] <= 60) &
    (df_all_brands["saturated_fat_100g"] <= 30) &

    (df_all_brands["carbohydrates_100g"] >= 5) &
    (df_all_brands["carbohydrates_100g"] <= 100) &

    (df_all_brands["sugars_100g"] <= 70) &
    (df_all_brands["fiber_100g"] <= 30) &

    (df_all_brands["proteins_100g"] <= 70) &
    (df_all_brands["salt_100g"] <= 4.5) &

    (df_all_brands["brands"].str.match(r"^[\x00-\x7F]+$", na=False)) &
    (df_all_brands["product_name"].str.match(r"^[\x00-\x7F]+$", na=False)) &
    
    non_zero_mask  
]

# %%
df_clean.describe()
# Out:
#        energy_kcal_100g     fat_100g  saturated_fat_100g  carbohydrates_100g  \
# count       7171.000000  7171.000000         7171.000000         7171.000000
# mean         425.335741    20.489960            4.735947           52.945370
# std          144.239936    12.656428            4.206205           19.842508
# min           21.000000     0.050000            0.006400            5.000000
# 25%          379.000000     8.125000            1.900000           50.000000
# 50%          480.000000    22.580645            3.570000           56.600000
# 75%          523.000000    30.577778            5.695000           64.900000
# max          833.333333    57.100000           29.400000           95.800000
#
#        sugars_100g   fiber_100g  proteins_100g    salt_100g   nova_group  \
# count  7171.000000  7171.000000    7171.000000  7171.000000  5241.000000
# mean     14.559793     4.168377       7.319577     1.072645     3.878268
# std      15.498837     3.020222       4.369153     0.612300     0.370252
# min       0.100000     0.010000       0.100000     0.000002     1.000000
# 25%       3.300000     2.460000       5.260000     0.666000     4.000000
# 50%       6.500000     3.610000       6.670000     1.002600     4.000000
# 75%      25.000000     4.900000       7.890000     1.400000     4.000000
# max      70.000000    30.000000      51.600000     4.500000     4.000000
#
#           created_t  last_modified_t
# count  7.171000e+03     7.171000e+03
# mean   1.624905e+09     1.725677e+09
# std    1.055916e+08     4.252976e+07
# min    1.332755e+09     1.494573e+09
# 25%    1.533357e+09     1.723236e+09
# 50%    1.639935e+09     1.746251e+09
# 75%    1.743437e+09     1.748666e+09
# max    1.753966e+09     1.753992e+09

# %%
df_clean
# Out:
#                       product_name  \
# 26       Bohnen Kidney - M-Classic
# 27                     Cheese Nibs
# 48                            Ritz
# 57          RITZ crackers original
# 60                Les cookies Coco
# ...                            ...
# 23345                     Chex mix
# 23346   Chex Mix Snack Mix Cheddar
# 23348  Chex Mix Remix Cheesy Pizza
# 23349       Honey Nut Flavour Chex
# 23350   Check Mix Bold Party Blend
#
#                                                   brands        barcode  \
# 26     M, M-Classic, MClassic, Migros, Migros: M-Classic  7616800800509
# 27                                                  Ritz  0066721029195
# 48                                                  Ritz  7622201747152
# 57                                                  Ritz       15983910
# 60                                         Matatie, Ritz  0377009601665
# ...                                                  ...            ...
# 23345                                               Chex  0016000214972
# 23346                                               Chex  0016000206984
# 23348                                               Chex  0016000205536
# 23349                                Chex, General Mills  0065633405226
# 23350                                               Chex  0016000126077
#
#                                               categories  \
# 26     en:plant-based-foods-and-beverages, en:plant-b...
# 27
# 48
# 57
# 60     en:snacks, en:sweet-snacks, en:specific-produc...
# ...                                                  ...
# 23345                                       en:snack-mix
# 23346                                        en:crackers
# 23348
# 23349  en:plant-based-foods-and-beverages, en:plant-b...
# 23350                                          en:snacks
#
#                                    countries  \
# 26     en:france, en:germany, en:switzerland
# 27                                 en:canada
# 48                           en:saudi-arabia
# 57                                 en:france
# 60                                 en:france
# ...                                      ...
# 23345                       en:united-states
# 23346                       en:united-states
# 23348                       en:united-states
# 23349                   en:canada, en:france
# 23350                       en:united-states
#
#                                                image_url  \
# 26     https://images.openfoodfacts.org/images/produc...
# 27                                                   N/A
# 48     https://images.openfoodfacts.org/images/produc...
# 57     https://images.openfoodfacts.org/images/produc...
# 60     https://images.openfoodfacts.org/images/produc...
# ...                                                  ...
# 23345  https://images.openfoodfacts.org/images/produc...
# 23346  https://images.openfoodfacts.org/images/produc...
# 23348  https://images.openfoodfacts.org/images/produc...
# 23349  https://images.openfoodfacts.org/images/produc...
# 23350  https://images.openfoodfacts.org/images/produc...
#
#                                         ingredients_text  energy_kcal_100g  \
# 26     red beans, water, cooking salt, acidifier: cit...              97.0
# 27                                                   N/A             500.0
# 48     Wheat Flour, Non Hydrogenated Vegetable Oil [P...             510.0
# 57                                                   N/A             484.0
# 60     Farines (farine de millet*,farine de riz blanc...             529.0
# ...                                                  ...               ...
# 23345  Degermed Yellow Corn Meal, Whole Wheat, Enrich...             414.0
# 23346  Degermed Yellow Corn Meal, Whole Wheat, Enrich...             433.0
# 23348                                                N/A             433.0
# 23349  Whole grain corn, Degermed corn meal, Sugar, C...             382.0
# 23350  whole wheat, degermed yellow corn meal, enrich...             414.0
#
#        fat_100g  saturated_fat_100g  ...  salt_100g  nutrition_grade  \
# 26         0.50               0.100  ...     0.7500                a
# 27        23.30               5.000  ...     1.5000          unknown
# 48        26.30              11.100  ...     1.0700          unknown
# 57        23.00              11.000  ...     1.3000          unknown
# 60        30.00              11.000  ...     0.3300                e
# ...         ...                 ...  ...        ...              ...
# 23345     12.10               1.720  ...     2.1600                d
# 23346     11.70               1.670  ...     1.7500                d
# 23348     13.30               5.000  ...     2.1700          unknown
# 23349      1.47               0.294  ...     1.6200                e
# 23350     10.34               1.720  ...     1.8393                d
#
#        nova_group  ecoscore_grade  \
# 26            3.0            None
# 27            NaN            None
# 48            4.0            None
# 57            NaN            None
# 60            4.0            None
# ...           ...             ...
# 23345         4.0            None
# 23346         4.0            None
# 23348         NaN            None
# 23349         4.0            None
# 23350         4.0            None
#
#                                                   labels  \
# 26
# 27
# 48
# 57
# 60     en:no-gluten, en:organic, en:crossed-grain-tra...
# ...                                                  ...
# 23345
# 23346
# 23348
# 23349  en:no-gluten, en:kosher, en:no-artificial-flav...
# 23350
#
#                              allergens                  packaging   created_t  \
# 26                                      en:box, en:can, en:canned  1437823409
# 27                                                                 1753052810
# 48              en:gluten, en:soybeans                             1715676935
# 57                                                                 1662204254
# 60                                                      en:packet  1627983121
# ...                                ...                        ...         ...
# 23345           en:gluten, en:soybeans                             1724275343
# 23346  en:gluten, en:milk, en:soybeans                             1723499763
# 23348                                                              1713149280
# 23349                          en:nuts                             1577892911
# 23350  en:gluten, en:milk, en:soybeans                             1524696090
#
#       last_modified_t searched_brand
# 26         1722792133          M&M's
# 27         1753052810           Ritz
# 48         1753792573           Ritz
# 57         1688203294           Ritz
# 60         1728357991           Ritz
# ...               ...            ...
# 23345      1753306635           Chex
# 23346      1748462124           Chex
# 23348      1749687013           Chex
# 23349      1713560486           Chex
# 23350      1749423732           Chex
#
# [7171 rows x 24 columns]

# %%
import os

# Automatically get your Windows username
username = os.getlogin()

# Construct full export path inside your OneDrive project folder
output_path = fr"C:\Users\{username}\OneDrive\02.DataScienceOD\exports\top_100_brands.csv"

# Save the DataFrame
df_clean.to_csv(output_path, index=False, encoding="utf-8")

print(f"File exported to: {output_path}")
# Out:
# File exported to: C:\Users\jverc\OneDrive\02.DataScienceOD\exports\top_100_brands.csv
