# %%
import requests
import pandas as pd

def fetch_products(query, query_type="search", page_size=100, page=1, sort_by="created_t"):

    if query_type == "brand":
        # Brand-based search
        url = f"https://world.openfoodfacts.org/brand/{query}.json"
        params = {
            "page_size": page_size,
            "page": page,
            "sort_by": sort_by
        }
    else:
        # Search term-based search
        url = "https://world.openfoodfacts.org/cgi/search.pl"
        params = {
            "search_terms": query,
            "search_simple": 1,
            "action": "process",
            "json": 1,
            "page_size": page_size,
            "page": page,
            "sort_by": sort_by
        }

    response = requests.get(url, params=params)
    if response.status_code != 200:
        raise Exception(f"API request failed: {response.status_code}")

    data = response.json()
    return data.get("products", [])

def extract_product_fields(product):
    nutriments = product.get("nutriments", {})
    return {
        # Identifiers
        "product_name": product.get("product_name", "N/A"),
        "brands": product.get("brands", "N/A"),
        "barcode": product.get("code", "N/A"),
        "categories": ", ".join(product.get("categories_tags", [])),
        "countries": ", ".join(product.get("countries_tags", [])),
        "image_url": product.get("image_url", "N/A"),
        "ingredients_text": product.get("ingredients_text", "N/A"),

        # Nutrition values
        "energy_kcal_100g": nutriments.get("energy-kcal_100g"),
        "fat_100g": nutriments.get("fat_100g"),
        "saturated_fat_100g": nutriments.get("saturated-fat_100g"),
        "carbohydrates_100g": nutriments.get("carbohydrates_100g"),
        "sugars_100g": nutriments.get("sugars_100g"),
        "fiber_100g": nutriments.get("fiber_100g"),
        "proteins_100g": nutriments.get("proteins_100g"),
        "salt_100g": nutriments.get("salt_100g"),

        # Nutrition grade and labels
        "nutrition_grade": product.get("nutrition_grades_tags", [None])[0],
        "nova_group": product.get("nova_group"),
        "ecoscore_grade": product.get("ecoscore_grade"),
        "labels": ", ".join(product.get("labels_tags", [])),
        "allergens": ", ".join(product.get("allergens_tags", [])),
        "packaging": ", ".join(product.get("packaging_tags", [])),

        # Timestamps
        "created_t": product.get("created_t"),
        "last_modified_t": product.get("last_modified_t"),
    }

def search_and_extract_all(query, query_type="search", page_size=100, sort_by="created_t", max_pages=None):

    all_records = []
    page = 1

    while True:
        print(f"Fetching page {page}...")
        products = fetch_products(query, query_type=query_type, page_size=page_size, page=page, sort_by=sort_by)

        if not products:
            print("No more products found.")
            break

        for product in products:
            record = extract_product_fields(product)
            all_records.append(record)

        if max_pages is not None and page >= max_pages:
            print("Reached max_pages limit.")
            break

        page += 1

    df = pd.DataFrame(all_records)
    return df

# %%
df_oreo = search_and_extract_all("oreo", query_type="brand")
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# No more products found.

# %%
df_oreo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724 entries, 0 to 723
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_name        724 non-null    object
#  1   brands              724 non-null    object
#  2   barcode             724 non-null    object
#  3   categories          724 non-null    object
#  4   countries           724 non-null    object
#  5   image_url           724 non-null    object
#  6   ingredients_text    724 non-null    object
#  7   energy_kcal_100g    606 non-null    float64
#  8   fat_100g            611 non-null    float64
#  9   saturated_fat_100g  596 non-null    float64
#  10  carbohydrates_100g  611 non-null    float64
#  11  sugars_100g         599 non-null    float64
#  12  fiber_100g          377 non-null    float64
#  13  proteins_100g       609 non-null    float64
#  14  salt_100g           584 non-null    float64
#  15  nutrition_grade     724 non-null    object
#  16  nova_group          295 non-null    float64
#  17  ecoscore_grade      0 non-null      object
#  18  labels              724 non-null    object
#  19  allergens           724 non-null    object
#  20  packaging           724 non-null    object
#  21  created_t           724 non-null    int64
#  22  last_modified_t     724 non-null    int64
# dtypes: float64(9), int64(2), object(12)
# memory usage: 130.2+ KB

# %%
# df_oreo_original = df_oreo[df_oreo["product_name"].str.lower() == "oreo original"]

df_oreo_canada = df_oreo[df_oreo["countries"].str.contains("en:canada", na=False)]

df_oreo_canada
# Out:
#                            product_name         brands        barcode  \
# 19                    Oreo Selena Gomez           Oreo  0066721029621
# 30            Sesame Flavored Thin Oreo           Oreo  6901668939562
# 56                   Peanut Butter Oreo           Oreo  0066721029706
# 127                           thin oreo           Oreo  0066721028990
# 145                     Oreo à l'érable           Oreo  0066721028921
# 173                         Golden oreo           Oreo  0066721028099
# 182                    The Orginal Oreo           Oreo  0066721028105
# 198                Oreo, double stuffed           Oreo  0066721028082
# 222                                Oreo           Oreo  0066721009555
# 239                                Oreo           Oreo  0066721027627
# 298                             Biscuit           Oreo  0066721026880
# 304  Hace crème saveur de chocolat noir           Oreo  0066721026668
# 331     Biscuits-sandwiches au chocolat           Oreo  0066721025708
# 683                            Original  Oreo,Mondelēz  7622300744663
# 721                       Original Oreo           Oreo  8410000810004
#
#                                             categories  \
# 19
# 30
# 56
# 127  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 145  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 173
# 182  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 198  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 222
# 239
# 298  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 304
# 331
# 683  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
# 721  en:snacks, en:sweet-snacks, en:biscuits-and-ca...
#
#                                              countries  \
# 19                                           en:canada
# 30                                           en:canada
# 56                                           en:canada
# 127                                          en:canada
# 145                               en:canada, en:france
# 173                                          en:canada
# 182                                          en:canada
# 198                                          en:canada
# 222                                          en:canada
# 239                                          en:canada
# 298                                          en:canada
# 304                                          en:canada
# 331                                          en:canada
# 683  en:belgium, en:canada, en:france, en:germany, ...
# 721  en:belgium, en:canada, en:denmark, en:finland,...
#
#                                              image_url  \
# 19                                                 N/A
# 30                                                 N/A
# 56                                                 N/A
# 127  https://images.openfoodfacts.org/images/produc...
# 145  https://images.openfoodfacts.org/images/produc...
# 173  https://images.openfoodfacts.org/images/produc...
# 182  https://images.openfoodfacts.org/images/produc...
# 198  https://images.openfoodfacts.org/images/produc...
# 222  https://images.openfoodfacts.org/images/produc...
# 239  https://images.openfoodfacts.org/images/produc...
# 298  https://images.openfoodfacts.org/images/produc...
# 304  https://images.openfoodfacts.org/images/produc...
# 331  https://images.openfoodfacts.org/images/produc...
# 683  https://images.openfoodfacts.org/images/produc...
# 721  https://images.openfoodfacts.org/images/produc...
#
#                                       ingredients_text  energy_kcal_100g  \
# 19                                                 N/A        483.000000
# 30                                                 N/A        490.000000
# 56                                                 N/A        483.000000
# 127  Sugars (sugar and/or golden sugar, glucose-fru...        483.000000
# 145  sucres, farine de blé, huile de palme modifié,...        517.000000
# 173  wheat flour, sugars (sugar, glucose-fructose),...        500.000000
# 182  sugars (sugar, glucose-fructose), wheat flour,...        471.000000
# 198  Sucres (sucre, glucose-fructose), Farine de bl...        482.758621
# 222                                                N/A        470.588235
# 239                                                N/A        454.545455
# 298  sugar, rolled oats, peanut butter (peanuts, hy...        500.000000
# 304                                                N/A        482.758621
# 331                                                N/A        482.758600
# 683  Farine de BLE, sucre, huile de palme, huile de...        476.000000
# 721  Farine de BLÉ, sucre, huile de palme, huile de...        472.000000
#
#       fat_100g  saturated_fat_100g  ...  proteins_100g  salt_100g  \
# 19   24.100000            8.620000  ...       3.450000   0.517000
# 30   22.400000            0.000000  ...       6.120000   0.969000
# 56   20.700000            5.170000  ...       6.900000   1.080000
# 127  20.700000            6.900000  ...       3.450000   0.819000
# 145  24.100000            8.620000  ...       3.450000   0.647000
# 173  20.588235            5.882353  ...       2.941176   0.845588
# 182  20.600000            5.880000  ...       2.940000   0.810000
# 198  24.137931            8.620690  ...       3.448276   0.646552
# 222  20.588235            5.882353  ...       2.941176   0.955882
# 239  20.454545            4.545455  ...       4.545455   0.965909
# 298  20.600000            5.880000  ...       8.820000   0.478000
# 304  20.689655            6.896552  ...       3.448276   0.905172
# 331  24.137900            8.620700  ...       3.448300   0.775862
# 683  20.000000            5.400000  ...       5.300000   0.730000
# 721  19.000000            5.400000  ...       5.600000   0.760000
#
#      nutrition_grade  nova_group  ecoscore_grade  \
# 19           unknown         NaN            None
# 30           unknown         NaN            None
# 56           unknown         NaN            None
# 127                e         4.0            None
# 145                e         4.0            None
# 173          unknown         4.0            None
# 182                e         4.0            None
# 198                e         4.0            None
# 222          unknown         NaN            None
# 239          unknown         NaN            None
# 298                e         4.0            None
# 304          unknown         NaN            None
# 331          unknown         NaN            None
# 683                e         4.0            None
# 721                e         4.0            None
#
#                                                 labels  \
# 19
# 30
# 56
# 127                                      en:cocoa-life
# 145
# 173
# 182
# 198
# 222
# 239
# 298
# 304
# 331
# 683  en:vegetarian, en:cocoa-life, en:green-dot, fr...
# 721  en:vegetarian, en:cocoa-life, en:green-dot, en...
#
#                            allergens  \
# 19
# 30
# 56
# 127           en:gluten, en:soybeans
# 145           en:gluten, en:soybeans
# 173           en:gluten, en:soybeans
# 182           en:gluten, en:soybeans
# 198           en:gluten, en:soybeans
# 222
# 239
# 298            en:gluten, en:peanuts
# 304
# 331
# 683           en:gluten, en:soybeans
# 721  en:gluten, en:milk, en:soybeans
#
#                                              packaging   created_t  \
# 19                                                      1749775318
# 30                                                      1747798716
# 56                                                      1742678696
# 127                                                     1713221135
# 145                                                     1705355336
# 173                                                     1689551884
# 182                                                     1686521334
# 198                                                     1678147546
# 222                                                     1659275985
# 239                                                     1650765666
# 298                                                     1625241196
# 304                                                     1621472558
# 331                                                     1613691612
# 683  en:plastic, en:box, en:cardboard, en:non-corru...  1484774630
# 721  en:plastic, en:box, en:cardboard, en:non-corru...  1337033518
#
#     last_modified_t
# 19       1749847609
# 30       1747798829
# 56       1746812779
# 127      1749582173
# 145      1724709049
# 173      1748705049
# 182      1746498416
# 198      1746655946
# 222      1748606206
# 239      1748219869
# 298      1751907098
# 304      1748649124
# 331      1748394936
# 683      1749242004
# 721      1748860006
#
# [15 rows x 23 columns]

# %%
output_path = r"C:\Users\jverc\OneDrive\02.DataScienceOD\exports\oreo_canada.csv" # Update the output path as needed

df_oreo_canada.to_csv(output_path, index=False, encoding="utf-8")
